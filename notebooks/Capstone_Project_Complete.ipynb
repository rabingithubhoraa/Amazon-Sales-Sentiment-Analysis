# %% [markdown]
# <a href="https://colab.research.google.com/github/rabingithubhoraa/Amazon-Sales-Sentiment-Analysis/blob/main/notebooks/01_Data_Loading_and_Inspection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Loading
#
# In this section, we load the Amazon product dataset into a pandas DataFrame. This initial step prepares the data for inspection, preprocessing, and analysis throughout the project.

# %%
# Import libs
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_PATH = Path("../data/raw/amazon.csv")
df = pd.read_csv(DATA_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1929/4102957748.py in <cell line: 0>()
#       1 DATA_PATH = Path("../data/raw/amazon.csv")
# ----> 2 df = pd.read_csv(DATA_PATH)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## Preview the Dataset
#
# The first five rows are displayed to verify that the dataset has been loaded correctly and to obtain an initial understanding of the available variables and their values.

# %%
# let's look at the data
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# (1465, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# ...

# %%
# check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# # we wil have to tackle with the missing value. either by removing or filling it.

# %%
# Check value counts for each category in 'category' column
print(df['category'].value_counts())
# Out:
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Electronics|Cameras&Photography|Accessories|Batteries&Chargers|BatteryChargers                                               1
# ...

# %%
# Splitting the 'category' column
categories_split = df['category'].str.split('|', expand=True)
# Making a copy of the original dataframe
new_df = df.copy()

# Adding 'main_category' and 'sub_category' to the copied dataframe
new_df['main_category'] = categories_split[0]
new_df['sub_category'] = categories_split[1]
new_df = new_df.drop(columns=['category'])
print(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0             ₹399       ₹1,099                 64%    4.2       24,269
# 1             ₹199         ₹349                 43%    4.0       43,994
# 2             ₹199       ₹1,899                 90%    3.9        7,928
# 3             ₹329         ₹699                 53%    4.2       94,363
# 4             ₹154         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
cat = new_df[['main_category', 'sub_category', 'product_id']]
cat_piv = pd.pivot_table(cat, index=['main_category', 'sub_category'], values='product_id', aggfunc='count')
cat_piv.rename(columns={'product_id': 'product_count'}, inplace=True)
print(cat_piv)
# Out:
#                                                                product_count
# main_category         sub_category
# Car&Motorbike         CarAccessories                                       1
# Computers&Accessories Accessories&Peripherals                            381
#                       Components                                           5
#                       ExternalDevices&DataStorage                         18
#                       Laptops                                              1
#                       Monitors                                             2
#                       NetworkingDevices                                   34
#                       Printers,Inks&Accessories                           11
#                       Tablets                                              1
# Electronics           Accessories                                         14
#                       Cameras&Photography                                 16
# ...

# %%
sns.histplot(new_df['rating'], kde=True)
plt.title('Distribution of Ratings')
plt.show()

# %%
new_df['rating'] = pd.to_numeric(new_df['rating'], errors='coerce')

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(data=new_df, x='main_category', y='rating')
plt.title('Boxplot of Ratings per Main Category')
plt.xticks(rotation=90)
plt.show()

# %%
new_df['discount_percentage'] = new_df['discount_percentage'].str.rstrip('%').astype('float') / 100.0  # Convert percentage to float
plt.figure(figsize=(15, 7))
sns.barplot(data=new_df, x='main_category', y='discount_percentage')
plt.title('Average Discount Percentage per Main Category')
plt.xticks(rotation=90)
plt.show()

# %%
top_reviewed = new_df.groupby('product_name')['review_id'].count().sort_values(ascending=False).head(10)
top_reviewed.plot(kind='barh')
plt.title('Top 10 Reviewed Products')
plt.gca().invert_yaxis()  # to have the product with the highest reviews at the top
plt.show()

# %%
correlation = new_df[['rating', 'discount_percentage']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(review for review in new_df['review_content'].dropna())
wordcloud = WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
user_review_counts = new_df['user_id'].value_counts().to_dict()
new_df['user_review_count'] = new_df['user_id'].map(user_review_counts)

# %%
print(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#   discounted_price actual_price  discount_percentage  rating rating_count  \
# 0             ₹399       ₹1,099                 0.64     4.2       24,269
# 1             ₹199         ₹349                 0.43     4.0       43,994
# 2             ₹199       ₹1,899                 0.90     3.9        7,928
# 3             ₹329         ₹699                 0.53     4.2       94,363
# 4             ₹154         ₹399                 0.61     4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(new_df['user_review_count'], kde=True)
plt.title('Distribution of Number of Reviews per User')
plt.xlabel('Number of Reviews')
plt.ylabel('Number of Users')
plt.show()

# %%
from textblob import TextBlob

new_df['sentiment'] = new_df['review_content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# %%
print(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#   discounted_price actual_price  discount_percentage  rating rating_count  \
# 0             ₹399       ₹1,099                 0.64     4.2       24,269
# 1             ₹199         ₹349                 0.43     4.0       43,994
# 2             ₹199       ₹1,899                 0.90     3.9        7,928
# 3             ₹329         ₹699                 0.53     4.2       94,363
# 4             ₹154         ₹399                 0.61     4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
new_df['actual_price'] = new_df['actual_price'].str.replace('[^\d.]', '', regex=True).astype(float)
new_df['discounted_price'] = new_df['discounted_price'].str.replace('[^\d.]', '', regex=True).astype(float)

# %%
new_df['discount_amount'] = new_df['actual_price'] - new_df['discounted_price']
print(new_df.head())
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#    discounted_price  actual_price  discount_percentage  rating rating_count  \
# 0             399.0        1099.0                 0.64     4.2       24,269
# 1             199.0         349.0                 0.43     4.0       43,994
# 2             199.0        1899.0                 0.90     3.9        7,928
# 3             329.0         699.0                 0.53     4.2       94,363
# 4             154.0         399.0                 0.61     4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# ...

# %%
new_df.columns
# Out:
# Index(['product_id', 'product_name', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_id', 'user_name', 'review_id', 'review_title', 'review_content',
#        'img_link', 'product_link', 'main_category', 'sub_category',
#        'user_review_count', 'sentiment', 'discount_amount'],
#       dtype='object')

# %% [markdown]
# Research Question: Can we predict the sentiment of a product review based on various product and user features? This question targets the sentiment analysis aspect but goes beyond just analyzing the text content of the reviews. Instead, it aims to combine textual analysis with other features to better predict sentiment, providing a holistic view of the factors influencing user sentiment. This approach will allow you to use a combination of NLP techniques and traditional machine learning. Steps to Approach this Research Question: Feature Engineering: Review Length: The length of a review might indicate whether it's positive or negative. python Copy code df['review_length'] = df['review_content'].apply(len) Title Sentiment: Often, the title of a review gives away its sentiment. python Copy code df['title_sentiment'] = df['review_title'].apply(lambda x: TextBlob(str(x)).sentiment.polarity) Data Preprocessing: Text Vectorization: Convert review_content into a numeric format. You can use TF-IDF, Count Vectorization, or word embeddings (like Word2Vec or GloVe). Scaling: Ensure that all features are on a similar scale. Use StandardScaler for features like review_length, discount_amount, and rating_count. One-Hot Encoding: Convert categorical columns like main_category and sub_category into a format suitable for modeling. Model Selection: Start with a simple model like Logistic Regression to establish a baseline. Move on to more complex models like Random Forest, Gradient Boosted Trees, or even Neural Networks. Remember, for sentiment, you can categorize them as positive, neutral, and negative based on the sentiment score you've calculated. Model Evaluation: Split data into training and test sets. Use metrics like accuracy, precision, recall, F1 score, and ROC-AUC to evaluate model performance. Conduct error analysis to see where your model is making mistakes. Hyperparameter Tuning: Optimize your model's parameters to get the best performance using techniques like GridSearchCV or RandomizedSearchCV. Insights and Visualization: Analyze feature importance if using tree-based models to understand what features are most influential in predicting sentiment. Visualize the distribution of true vs. predicted sentiments. Visualize the error across different categories or products to spot trends. Deployment (Optional): If this is meant for real-time use, consider deploying your model as an API using tools like Flask or FastAPI. This would allow for real-time sentiment prediction of reviews, potentially useful for real-world applications. Documentation and Reporting: Write a comprehensive report detailing your methodology, challenges faced, model choices, evaluations, and insights derived. Create a presentation to convey the most crucial findings succinctly. Feedback and Iteration: If possible, gather feedback on your predictions and refine the model. Consider creating a mechanism for continuous learning where the model can be retrained with new data.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')  # considering top 5000 features
tfidf_matrix = tfidf_vectorizer.fit_transform(new_df['review_content'])

# Convert to DataFrame for easier manipulation later
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# %%
# Convert rating_count to an integer by removing commas
# Simply convert to float
new_df['rating_count'] = new_df['rating_count'].str.replace(',', '').astype(float)


# Now, proceed with scaling
scaler = StandardScaler()
new_df[features_to_scale] = scaler.fit_transform(new_df[features_to_scale])

# %%
main_category_dummies = pd.get_dummies(new_df['main_category'], prefix='main_category')
sub_category_dummies = pd.get_dummies(new_df['sub_category'], prefix='sub_category')

# Concatenate the dummy variable columns onto the original DataFrame
new_df = pd.concat([new_df, main_category_dummies, sub_category_dummies], axis=1)

# Optionally, drop original categorical columns to avoid redundancy
new_df.drop(['main_category', 'sub_category'], axis=1, inplace=True)

# %%
final_df = pd.concat([new_df, tfidf_df], axis=1)
final_df.columns
# Out:
# Index(['product_id', 'product_name', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_id', 'user_name',
#        ...
#        'உட', 'உள', 'ஏற', 'கட', 'கம', 'தன', 'நன', 'னத', 'ளத', '𝗔𝗱𝗵𝗲𝘀𝗶𝗼𝗻'],
#       dtype='object', length=5058)

# %%
# Drop columns that are not features for the model
columns_to_drop = ['product_id', 'product_name', 'about_product', 'user_id', 'user_name']

# Ensure the columns exist in final_df before dropping
columns_to_drop = [col for col in columns_to_drop if col in final_df.columns]

features = final_df.drop(columns=columns_to_drop)
target = new_df['sentiment_category']  # Ensure that this target column is aligned with final_df

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Get columns with data type object (usually strings)
non_numeric_cols = features.select_dtypes(include='object').columns

# Print these columns to inspect them
print(non_numeric_cols)


# Filling NaNs with a default value
X_train = X_train.fillna(0)  # For numeric columns
X_test = X_test.fillna(0)

# Retry training the model
lr = LogisticRegression(max_iter=10000)
lr.fit(X_train, y_train)
predictions = lr.predict(X_test)

print("Accuracy:", accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Index(['review_id', 'review_title', 'review_content', 'img_link',
#        'product_link', 'sentiment_category'],
#       dtype='object')
# Accuracy: 0.9761092150170648
#               precision    recall  f1-score   support
#
#      Neutral       0.98      1.00      0.99       285
#     Positive       0.67      0.25      0.36         8
#
#     accuracy                           0.98       293
#    macro avg       0.82      0.62      0.68       293
# weighted avg       0.97      0.98      0.97       293

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_predictions = rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, rf_predictions))
print(classification_report(y_test, rf_predictions))
# Out:
# Accuracy: 0.9761092150170648
#               precision    recall  f1-score   support
#
#      Neutral       0.98      1.00      0.99       285
#     Positive       0.67      0.25      0.36         8
#
#     accuracy                           0.98       293
#    macro avg       0.82      0.62      0.68       293
# weighted avg       0.97      0.98      0.97       293

# %% [markdown]
# Predicting Discounted price of products
# #simple linear regression model
# independent variable- actual price
# dependent variable - discounted price

# %%
X = df_num['actual_price'].values.reshape(-1, 1)
y = df_num['discounted_price'].values.reshape(-1, 1)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Splitting the dataset into the Training Set and Test Set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21)
# Creating the linear regression object and fitting it to the training set
reg = LinearRegression()
reg.fit(X_train, y_train)y_pred = reg.predict(X_test)
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, reg.predict(X_train), color='blue')
plt.title('Actual Price vs Discounted Price (Training set)')
plt.xlabel('Actual Price')
plt.ylabel('Discounted Price')
plt.show()
r2_score = reg.score(X_test, y_test)
print(f"R^2 Value: {r2_score}")
intercept = reg.intercept_
print(f"Intercept: {intercept}")
coefficient = reg.coef_
print(f"Coefficient: {coefficient}")
